# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from datetime import timedelta
from dateutil.parser import parse
from datetime import datetime
from pandas.tseries.offsets import Hour, Minute
from pandas.tseries.offsets import Day, MonthEnd
import pytz
from pandas.tseries.offsets import Hour
from pandas.tseries.frequencies import to_offset
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
#df = pd.read_csv('Wind_deseason.csv')
df = pd.read_csv('PV_deseason_15.csv')
lags=len(df['310_PV_1'])
print(lags)
# Out:
# 35136

# %%
sns.set_style("dark")

acf_plot = plot_acf(df['310_PV_1'], lags=120)
plt.xlabel("Time lags (k)",fontsize=18)
plt.ylabel("Autocorrelation",fontsize=18)
plt.rc('xtick', labelsize=12) #
plt.rc('ytick', labelsize=12)
plt.savefig('PV_autocorrelation.png')

# %%
acf_plot = plot_acf(df['310_PV_1'], lags=20)

# %%
sns.set_style("dark")
plot_pacf(df['310_PV_1'], lags=120, alpha = 0.05)
plt.xlabel("Time lags (k)",fontsize=18)
plt.ylabel("Autocorrelation",fontsize=18)
plt.rc('xtick', labelsize=12) #
plt.rc('ytick', labelsize=12)
plt.savefig('PV_partialautocorrelation.png')
# Out:
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
