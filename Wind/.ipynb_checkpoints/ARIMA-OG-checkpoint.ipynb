# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from datetime import timedelta
from dateutil.parser import parse
from datetime import datetime
from pandas.tseries.offsets import Hour, Minute
from pandas.tseries.offsets import Day, MonthEnd
import pytz
from pandas.tseries.offsets import Hour
from pandas.tseries.frequencies import to_offset
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.stattools import acf
from pmdarima.arima import auto_arima
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error

# %%
#df = pd.read_csv('Wind_deseason.csv')
df = pd.read_csv('Wind_deseason_15.csv', parse_dates=[0], index_col=0)

# %%
autoAR = auto_arima(df['309_WIND_1'], trace = True, random_state = 42)
autoAR.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=38.04 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=235192.883, Time=0.63 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=227314.921, Time=0.82 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=228054.129, Time=3.73 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=235190.889, Time=0.34 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=227201.152, Time=1.08 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=227195.874, Time=2.41 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : AIC=227172.882, Time=3.11 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : AIC=227174.647, Time=3.92 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=226823.742, Time=48.56 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=40.41 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=227176.877, Time=6.17 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=48.12 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=28.00 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=51.35 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : AIC=inf, Time=19.33 sec
#
# Best model:  ARIMA(4,1,1)(0,0,0)[0] intercept
# Total fit time: 296.050 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                35136
# Model:               SARIMAX(4, 1, 1)   Log Likelihood             -113404.871
# Date:                Mon, 08 May 2023   AIC                         226823.742
# Time:                        11:16:15   BIC                         226883.011
# Sample:                    01-01-2020   HQIC                        226842.617
#                          - 01-01-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0005      0.000      0.948      0.343      -0.000       0.001
# ar.L1          1.4525      0.002    583.629      0.000       1.448       1.457
# ar.L2         -0.5202      0.004   -128.495      0.000      -0.528      -0.512
# ar.L3          0.0541      0.004     12.801      0.000       0.046       0.062
# ar.L4         -0.0119      0.002     -5.133      0.000      -0.016      -0.007
# ma.L1         -0.9869      0.002   -598.305      0.000      -0.990      -0.984
# sigma2        36.7741      0.077    477.269      0.000      36.623      36.925
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.40   Jarque-Bera (JB):           1276651.68
# Prob(Q):                              0.53   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.84   Skew:                             0.84
# Prob(H) (two-sided):                  0.00   Kurtosis:                        32.48
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
tss = TimeSeriesSplit(n_splits = 5, test_size = 20, gap = 0)

# %%
#df = df.sort_index()
#auto_arima(df['309_WIND_1'])

# %%
mse = []

for train_indx, val_indx in tss.split(df):
    train = df.iloc[train_indx]
    test = df.iloc[val_indx]
    
    mod = ARIMA(train['309_WIND_1'], order = (4,1,1))
    result = mod.fit()
    print(result.summary())
    
    start = len(train)
    end = len(train)+1
    
    pred = result.predict(start = start, end = end)
    
    
    error = 0.5*(test['309_WIND_1'][0] - pred[0])**2
    mse.append(error)
    
    #print(pred)
    
    #print(test['309_WIND_1'][0])
    #print(pred[0])
# Out:
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   self._init_dates(dates, freq)
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   self._init_dates(dates, freq)
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   self._init_dates(dates, freq)
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             309_WIND_1   No. Observations:                35036
# Model:                 ARIMA(4, 1, 1)   Log Likelihood             -113055.854
# Date:                Mon, 08 May 2023   AIC                         226123.707
# Time:                        11:22:30   BIC                         226174.492
# Sample:                    01-01-2020   HQIC                        226139.883
#                          - 12-30-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.4580      0.002    729.480      0.000       1.454       1.462
# ar.L2         -0.5171      0.004   -128.184      0.000      -0.525      -0.509
# ar.L3          0.0429      0.004      9.931      0.000       0.034       0.051
# ar.L4       6.759e-05      0.002      0.029      0.977      -0.004       0.005
# ma.L1         -0.9981      0.000  -2415.905      0.000      -0.999      -0.997
# sigma2        37.2215      0.077    486.366      0.000      37.071      37.371
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):           1276841.03
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.84   Skew:                             0.88
# Prob(H) (two-sided):                  0.00   Kurtosis:                        32.52
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   self._init_dates(dates, freq)
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   self._init_dates(dates, freq)
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   self._init_dates(dates, freq)
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             309_WIND_1   No. Observations:                35056
# Model:                 ARIMA(4, 1, 1)   Log Likelihood             -113127.337
# Date:                Mon, 08 May 2023   AIC                         226266.675
# Time:                        11:22:49   BIC                         226317.463
# Sample:                    01-01-2020   HQIC                        226282.851
#                          - 12-31-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.4578      0.002    727.068      0.000       1.454       1.462
# ar.L2         -0.5171      0.004   -128.630      0.000      -0.525      -0.509
# ar.L3          0.0431      0.004     10.037      0.000       0.035       0.052
# ar.L4         -0.0005      0.002     -0.222      0.825      -0.005       0.004
# ma.L1         -0.9974      0.000  -2011.908      0.000      -0.998      -0.996
# sigma2        37.0958      0.076    488.592      0.000      36.947      37.245
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):           1275389.14
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.84   Skew:                             0.87
# Prob(H) (two-sided):                  0.00   Kurtosis:                        32.50
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   self._init_dates(dates, freq)
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   self._init_dates(dates, freq)
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   self._init_dates(dates, freq)
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             309_WIND_1   No. Observations:                35076
# Model:                 ARIMA(4, 1, 1)   Log Likelihood             -113214.274
# Date:                Mon, 08 May 2023   AIC                         226440.548
# Time:                        11:23:07   BIC                         226491.339
# Sample:                    01-01-2020   HQIC                        226456.725
#                          - 12-31-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.4589      0.002    723.871      0.000       1.455       1.463
# ar.L2         -0.5185      0.004   -128.649      0.000      -0.526      -0.511
# ar.L3          0.0443      0.004     10.295      0.000       0.036       0.053
# ar.L4         -0.0016      0.002     -0.702      0.483      -0.006       0.003
# ma.L1         -0.9972      0.001  -1900.593      0.000      -0.998      -0.996
# sigma2        37.2217      0.076    487.250      0.000      37.072      37.371
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):           1269594.27
# Prob(Q):                              0.90   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.84   Skew:                             0.87
# Prob(H) (two-sided):                  0.00   Kurtosis:                        32.42
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   self._init_dates(dates, freq)
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   self._init_dates(dates, freq)
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   self._init_dates(dates, freq)
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             309_WIND_1   No. Observations:                35096
# Model:                 ARIMA(4, 1, 1)   Log Likelihood             -113271.412
# Date:                Mon, 08 May 2023   AIC                         226554.825
# Time:                        11:23:26   BIC                         226605.620
# Sample:                    01-01-2020   HQIC                        226571.002
#                          - 12-31-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.4594      0.002    732.548      0.000       1.455       1.463
# ar.L2         -0.5172      0.004   -128.200      0.000      -0.525      -0.509
# ar.L3          0.0411      0.004      9.514      0.000       0.033       0.050
# ar.L4          0.0012      0.002      0.504      0.614      -0.003       0.006
# ma.L1         -0.9986      0.000  -2953.459      0.000      -0.999      -0.998
# sigma2        37.2732      0.077    485.712      0.000      37.123      37.424
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):           1268470.84
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.84   Skew:                             0.87
# Prob(H) (two-sided):                  0.00   Kurtosis:                        32.40
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   self._init_dates(dates, freq)
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   self._init_dates(dates, freq)
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   self._init_dates(dates, freq)
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             309_WIND_1   No. Observations:                35116
# Model:                 ARIMA(4, 1, 1)   Log Likelihood             -113326.922
# Date:                Mon, 08 May 2023   AIC                         226665.844
# Time:                        11:23:46   BIC                         226716.642
# Sample:                    01-01-2020   HQIC                        226682.022
#                          - 12-31-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.4593      0.002    729.346      0.000       1.455       1.463
# ar.L2         -0.5175      0.004   -128.661      0.000      -0.525      -0.510
# ar.L3          0.0411      0.004      9.552      0.000       0.033       0.050
# ar.L4          0.0006      0.002      0.252      0.801      -0.004       0.005
# ma.L1         -0.9976      0.000  -2132.601      0.000      -0.999      -0.997
# sigma2        37.1663      0.076    487.542      0.000      37.017      37.316
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):           1270934.60
# Prob(Q):                              0.90   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.84   Skew:                             0.87
# Prob(H) (two-sided):                  0.00   Kurtosis:                        32.42
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
print(mse)
# Out:
# [9.415404946522695, 6.694533012071436, 12.909898836333191, 0.649468791621324, 0.08325814473169103]

# %%
mse2 = []

for train_indx, val_indx in tss.split(df):
    train = df.iloc[train_indx]
    test = df.iloc[val_indx]
    
    mod = ARIMA(train['309_WIND_1'], order = (20,1,2))
    result = mod.fit()
    print(result.summary())
    
    start = len(train)
    end = len(train)+1
    
    pred = result.predict(start = start, end = end)
    
    
    error = 0.5*(test['309_WIND_1'][0] - pred[0])**2
    mse2.append(error)
    
    #print(pred)
    
    #print(test['309_WIND_1'][0])
    #print(pred[0])
# Out:
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   self._init_dates(dates, freq)
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   self._init_dates(dates, freq)
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   self._init_dates(dates, freq)
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             309_WIND_1   No. Observations:                35036
# Model:                ARIMA(20, 1, 2)   Log Likelihood             -113018.791
# Date:                Mon, 08 May 2023   AIC                         226083.581
# Time:                        11:27:28   BIC                         226278.256
# Sample:                    01-01-2020   HQIC                        226145.587
#                          - 12-30-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5300      0.068      7.797      0.000       0.397       0.663
# ar.L2          0.8405      0.099      8.470      0.000       0.646       1.035
# ar.L3         -0.4325      0.035    -12.241      0.000      -0.502      -0.363
# ar.L4          0.0208      0.005      4.110      0.000       0.011       0.031
# ar.L5          0.0044      0.004      1.024      0.306      -0.004       0.013
# ar.L6          0.0167      0.005      3.654      0.000       0.008       0.026
# ar.L7         -0.0095      0.004     -2.138      0.032      -0.018      -0.001
# ar.L8          0.0018      0.004      0.457      0.648      -0.006       0.009
# ar.L9         -0.0010      0.005     -0.207      0.836      -0.010       0.008
# ar.L10        -0.0217      0.005     -4.576      0.000      -0.031      -0.012
# ar.L11         0.0187      0.004      4.434      0.000       0.010       0.027
# ar.L12         0.0186      0.005      3.840      0.000       0.009       0.028
# ar.L13        -0.0154      0.005     -3.264      0.001      -0.025      -0.006
# ar.L14        -0.0214      0.005     -4.715      0.000      -0.030      -0.013
# ar.L15        -0.0124      0.005     -2.331      0.020      -0.023      -0.002
# ar.L16         0.0297      0.005      5.938      0.000       0.020       0.040
# ar.L17         0.0211      0.006      3.583      0.000       0.010       0.033
# ar.L18        -0.0055      0.005     -1.020      0.308      -0.016       0.005
# ar.L19        -0.0114      0.005     -2.359      0.018      -0.021      -0.002
# ar.L20         0.0023      0.004      0.528      0.598      -0.006       0.011
# ma.L1         -0.0700      0.068     -1.031      0.302      -0.203       0.063
# ma.L2         -0.9295      0.068    -13.695      0.000      -1.063      -0.796
# sigma2        37.0454      0.078    477.377      0.000      36.893      37.198
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):           1255061.97
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.84   Skew:                             0.87
# Prob(H) (two-sided):                  0.00   Kurtosis:                        32.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   self._init_dates(dates, freq)
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   self._init_dates(dates, freq)
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency 15T will be used.
#   self._init_dates(dates, freq)
# C:\Users\bvits\anaconda3\envs\modern_ts\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             309_WIND_1   No. Observations:                35116
# Model:                ARIMA(20, 1, 2)   Log Likelihood             -113290.683
# Date:                Mon, 08 May 2023   AIC                         226627.366
# Time:                        11:40:53   BIC                         226822.093
# Sample:                    01-01-2020   HQIC                        226689.382
#                          - 12-31-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5564      0.111      5.008      0.000       0.339       0.774
# ar.L2          0.8017      0.162      4.942      0.000       0.484       1.120
# ar.L3         -0.4185      0.058     -7.256      0.000      -0.532      -0.305
# ar.L4          0.0185      0.007      2.752      0.006       0.005       0.032
# ar.L5          0.0046      0.005      0.931      0.352      -0.005       0.014
# ar.L6          0.0180      0.005      3.511      0.000       0.008       0.028
# ar.L7         -0.0099      0.004     -2.201      0.028      -0.019      -0.001
# ar.L8          0.0010      0.004      0.269      0.788      -0.006       0.009
# ar.L9         -0.0002      0.005     -0.033      0.974      -0.009       0.009
# ar.L10        -0.0213      0.005     -4.514      0.000      -0.031      -0.012
# ar.L11         0.0172      0.005      3.783      0.000       0.008       0.026
# ar.L12         0.0159      0.006      2.808      0.005       0.005       0.027
# ar.L13        -0.0130      0.005     -2.691      0.007      -0.022      -0.004
# ar.L14        -0.0200      0.005     -4.409      0.000      -0.029      -0.011
# ar.L15        -0.0117      0.006     -2.060      0.039      -0.023      -0.001
# ar.L16         0.0301      0.005      5.986      0.000       0.020       0.040
# ar.L17         0.0200      0.006      3.194      0.001       0.008       0.032
# ar.L18        -0.0050      0.005     -0.930      0.353      -0.016       0.006
# ar.L19        -0.0115      0.005     -2.345      0.019      -0.021      -0.002
# ar.L20         0.0011      0.004      0.255      0.799      -0.008       0.010
# ma.L1         -0.0954      0.111     -0.859      0.390      -0.313       0.122
# ma.L2         -0.9036      0.111     -8.143      0.000      -1.121      -0.686
# sigma2        37.1884      0.078    475.989      0.000      37.035      37.342
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):           1258405.40
# Prob(Q):                              0.93   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.84   Skew:                             0.87
# Prob(H) (two-sided):                  0.00   Kurtosis:                        32.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
print(mse2)
# Out:
# [12.108351695853912, 6.814641362970427, 9.78025702862989, 0.567411204813471, 0.15349878593382987]

# %%
mse3 = []

for train_indx, val_indx in tss.split(df):
    train = df.iloc[train_indx]
    test = df.iloc[val_indx]
    
    pred = train['309_WIND_1'][-1]
    
    
    error = 0.5*(test['309_WIND_1'][0] - pred)**2
    mse3.append(error)

# %%
print(mse3)
# Out:
# [156.0802117142116, 5.784745933917925, 113.52324988197745, 0.12569876206704678, 0.008705038878608299]
