# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from datetime import timedelta
from dateutil.parser import parse
from datetime import datetime
from pandas.tseries.offsets import Hour, Minute
from pandas.tseries.offsets import Day, MonthEnd
import pytz
from pandas.tseries.offsets import Hour
from pandas.tseries.frequencies import to_offset
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import seaborn as sns

# %%
#df = pd.read_csv('Wind_deseason.csv')
df = pd.read_csv('Wind_deseason_15.csv')

# %%
sns.set_style("dark")

acf_plot = plot_acf(df['309_WIND_1'], lags=120)
plt.xlabel("Time lags (k)",fontsize=18)
plt.ylabel("Autocorrelation",fontsize=18)
plt.rc('xtick', labelsize=12) #
plt.rc('ytick', labelsize=12)
plt.savefig('Wind_autocorrelation.png')

# %%
acf_plot = plot_acf(df['317_WIND_1'], lags=30000)

# %%
acf_plot = plot_acf(df['317_WIND_1'], lags=20)

# %%
sns.set_style("dark")
plot_pacf(df['309_WIND_1'], lags=120, alpha = 0.05)
plt.xlabel("Time lags (k)",fontsize=18)
plt.ylabel("Partial Autocorrelation",fontsize=18)
plt.rc('xtick', labelsize=12) #
plt.rc('ytick', labelsize=12)
plt.savefig('Wind_partialautocorrelation.png')
