# %%
import numpy as np
import pandas as pd
from pandas.tseries.offsets import Hour, Minute
from pandas.tseries.offsets import Day, MonthEnd
from pandas.tseries.offsets import Hour

# %%
df1 = pd.read_csv('Naive_errors.csv', index_col=0)
df2 = pd.read_csv('acfARIMA_errors_final.csv',index_col=0)
df3 = pd.read_csv('autoARIMA_errors_final.csv',index_col=0)
df4 = pd.read_csv('LSTM_errors_notscaled.csv',index_col=0)
df5 = pd.read_csv('GBDT_errors.csv',index_col=0)
df6 = pd.read_csv('LSTM_errors_notscaled_random.csv',index_col=0)
df7 = pd.read_csv('GBDT_errors_randomsearch.csv',index_col=0)

# %%
def computeMSEevery5(df):
    
    Result = []
    for col in df.columns:
        
        Result.append(df[col].mean())
        
    Result
    
    return Result

# %%
def computeSTDevery5(df):
    
    Result = []
    for col in df.columns:
        
        Result.append(df[col].std())
        
    Result
    
    return Result

# %%
Naive = computeMSEevery5(df1)
acf = computeMSEevery5(df2)
auto = computeMSEevery5(df3)
LSTM = computeMSEevery5(df4)
GBDT = computeMSEevery5(df5)
LSTM_rand = computeMSEevery5(df6)
GBDT_rand = computeMSEevery5(df7)

# %%
print(Naive)
# Out:
# [16.966240333320624, 3.851532942723831, 3.851532942723831, 8.060414107696444]

# %%
print(acf)
# Out:
# [58.44932574104786, 43.77067292916146, 16.282332393527707, 39.854061596166915]

# %%
print(auto)
# Out:
# [58.44932574104786, 43.65704610633139, 16.282332393527707, 39.801854298674236]

# %%
print(LSTM)
# Out:
# [19.014287748988373, 13.125346742698545, 11.77575344039657, 31.366956085075245]

# %%
print(GBDT)
# Out:
# [19.470549634429627, 5.304451799367604, 2.514716321907055, 8.762090947180802]

# %%
print(LSTM_rand)
# Out:
# [16.199673596230145, 6.065360986157668, 3.8156166528118547, 8.080170611822945]

# %%
print(GBDT_rand)
# Out:
# [16.42419121073284, 3.6840153706322445, 2.2056397847949327, 6.809665141764061]

# %%
d = {'Naive':Naive,'acf':acf,'auto':auto,'LSTM':LSTM,'GBDT':GBDT,'LSTM_rand':LSTM_rand,'GBDT_rand':GBDT_rand}

df_MSEs = pd.DataFrame({k:pd.Series(v) for k,v in d.items()})
df_MSEs['seasons'] = ['season 1', 'season 2', 'season 3', 'season 4']
df_MSEs.set_index('seasons')
# Out:
#               Naive        acf       auto       LSTM       GBDT  LSTM_rand  \
# seasons
# season 1  16.966240  58.449326  58.449326  19.014288  19.470550  16.199674
# season 2   3.851533  43.770673  43.657046  13.125347   5.304452   6.065361
# season 3   3.851533  16.282332  16.282332  11.775753   2.514716   3.815617
# season 4   8.060414  39.854062  39.801854  31.366956   8.762091   8.080171
#
#           GBDT_rand
# seasons
# season 1  16.424191
# season 2   3.684015
# season 3   2.205640
# season 4   6.809665

# %%
df_MSEs

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
rng = np.random.RandomState(0)
x = np.linspace(0, 10, 500)
y = [Naive,acf,auto,LSTM,GBDT,LSTM_rand,GBDT_rand]


season1 = []
season2 = []
season3 = []
season4 = []
for model in y:
    season1.append(model[0])
    season2.append(model[1])
    season3.append(model[2])
    season4.append(model[3])
# Out:
# [<matplotlib.lines.Line2D at 0x29089d075b0>,
#  <matplotlib.lines.Line2D at 0x29089d07610>,
#  <matplotlib.lines.Line2D at 0x29089d07640>,
#  <matplotlib.lines.Line2D at 0x29089d07730>,
#  <matplotlib.lines.Line2D at 0x29089d07820>,
#  <matplotlib.lines.Line2D at 0x29089d07910>,
#  <matplotlib.lines.Line2D at 0x29089d07a00>]

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.plot([season1,season2,season3,season4])
plt.legend(['Naive','ACF','AUTO','LSTM','GBDT', 'LSTM rand', 'GBDT rand'], ncol=2, loc='upper right', fontsize="23")

# %%
Naive = computeSTDevery5(df1)
acf = computeSTDevery5(df2)
auto = computeSTDevery5(df3)
LSTM = computeSTDevery5(df4)
GBDT = computeSTDevery5(df5)
LSTM_rand = computeSTDevery5(df6)
GBDT_rand = computeSTDevery5(df7)

# %%
d = {'Naive':Naive,'acf':acf,'auto':auto,'LSTM':LSTM,'GBDT':GBDT,'LSTM_rand':LSTM_rand,'GBDT_rand':GBDT_rand}

df_MSEs = pd.DataFrame({k:pd.Series(v) for k,v in d.items()})
df_MSEs['seasons'] = ['season 1', 'season 2', 'season 3', 'season 4']
df_MSEs.set_index('seasons')
# Out:
#               Naive         acf        auto       LSTM       GBDT  LSTM_rand  \
# seasons
# season 1  68.626453  123.374073  123.374073  53.237472  55.146986  61.622357
# season 2  15.021877   98.424934  104.472273  30.993544  25.551437  15.609724
# season 3  15.021877   29.447861   29.447861  23.213447  11.691946  13.908764
# season 4  33.868318   77.326622   86.521946  71.809148  35.699156  34.180660
#
#           GBDT_rand
# seasons
# season 1  56.420991
# season 2  16.269862
# season 3  11.199899
# season 4  30.996210

# %%
y = [Naive,acf,auto,LSTM,GBDT,LSTM_rand,GBDT_rand]


season1 = []
season2 = []
season3 = []
season4 = []
for model in y:
    season1.append(model[0])
    season2.append(model[1])
    season3.append(model[2])
    season4.append(model[3])

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
plt.plot([season1,season2,season3,season4])
plt.legend(['Naive','ACF','AUTO','LSTM','GBDT', 'LSTM rand', 'GBDT rand'], ncol=2, loc='upper right', fontsize="23")
